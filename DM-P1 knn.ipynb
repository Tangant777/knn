# %%
#imports
import pandas as pd
import numpy as np

# %%
#read data file
Rice=pd.read_csv(r'/content/Rice.csv')
Rice
# Out:
#        Area   Perimeter  Major_Axis_Length Minor_Axis_Length  Eccentricity  \
# 0      7551  369.063995         163.408829       59.53240585      0.931275
# 1      8546  388.580994         172.519959       63.34475327      0.930152
# 2      7833  373.157013         162.516434       63.56500244      0.920336
# 3      9292  414.118988         183.639710       64.87107086      0.935528
# 4      7943  362.673004         154.886322       65.93088531      0.904877
# ...     ...         ...                ...               ...           ...
# 3822  10151  420.899994         181.995575       72.09951019      0.918181
# 3823  10222  423.497009         182.800247        72.1242981      0.918873
# 3824   9216  384.342011         163.291626       72.26079559      0.896756
# 3825  11377  452.407989         201.306259       72.28141785      0.933314
# 3826   9598  397.000000         172.006790       72.28364563      0.907414
#
#      Convex_Area    Extent     Class
# ...

# %%
#check columns data type
Rice.dtypes
# Out:
# Area                  object
# Perimeter            float64
# Major_Axis_Length    float64
# Minor_Axis_Length     object
# Eccentricity         float64
# Convex_Area           object
# Extent               float64
# Class                 object
# dtype: object

# %%
#10 first data
Rice.head(10)
# Out:
#    Area   Perimeter  Major_Axis_Length Minor_Axis_Length  Eccentricity  \
# 0  7551  369.063995         163.408829       59.53240585      0.931275
# 1  8546  388.580994         172.519959       63.34475327      0.930152
# 2  7833  373.157013         162.516434       63.56500244      0.920336
# 3  9292  414.118988         183.639710       64.87107086      0.935528
# 4  7943  362.673004         154.886322       65.93088531      0.904877
# 5  9414  407.825012         179.545883       66.91815948      0.927949
# 6  9908  432.769012         188.187683       67.69534302      0.933059
# 7  8709  383.527008         164.193893       67.93288422      0.910397
# 8  9426  402.709992         175.974289       68.60753632      0.920869
# 9  9273  406.402008         173.414093       68.80253601      0.917925
#
#   Convex_Area    Extent     Class
# 0        7723  0.756462  Osmancik
# 1        8685  0.735456  Osmancik
# 2        8015  0.769752  Osmancik
# 3        9442  0.501078  Osmancik
# ...

# %%
#10 end data
Rice.tail(10)
# Out:
#        Area   Perimeter  Major_Axis_Length Minor_Axis_Length  Eccentricity  \
# 3817   9751  412.597992         175.450638       71.44275665      0.913341
# 3818   9802  412.368988         176.165573       71.48280334      0.913975
# 3819   8501  371.024994         153.896255       71.51190948      0.885481
# 3820   8850  381.433990         159.251205       71.76094818      0.892718
# 3821  10713  443.403992         192.886185       71.78689575      0.928164
# 3822  10151  420.899994         181.995575       72.09951019      0.918181
# 3823  10222  423.497009         182.800247        72.1242981      0.918873
# 3824   9216  384.342011         163.291626       72.26079559      0.896756
# 3825  11377  452.407989         201.306259       72.28141785      0.933314
# 3826   9598  397.000000         172.006790       72.28364563      0.907414
#
#      Convex_Area    Extent     Class
# 3817       10034  0.714359  Osmancik
# 3818        9991  0.566950  Osmancik
# ...

# %%
#replace unknown sells with null
Rice.replace('???',np.nan,inplace=True)

# %%
#change wrong data types to float
Rice['Area']=Rice['Area'].astype('float64')
Rice['Minor_Axis_Length']=Rice['Minor_Axis_Length'].astype('float64')
Rice['Convex_Area']=Rice['Convex_Area'].astype('float64')
Rice.dtypes
# Out:
# Area                 float64
# Perimeter            float64
# Major_Axis_Length    float64
# Minor_Axis_Length    float64
# Eccentricity         float64
# Convex_Area          float64
# Extent               float64
# Class                 object
# dtype: object

# %%
#Number of rows and colomns
print("Number of rows: ",len(Rice))
print("Number of columns: ",len(Rice.columns))
# Out:
# Number of rows:  3827
# Number of columns:  8

# %%
#min, Max of features
print("min of features:\n",Rice.min())
print("\n\nMax of features:\n",Rice.max())
# Out:
# min of features:
#  Area                     7551.0
# Perimeter            359.100006
# Major_Axis_Length    145.264465
# Minor_Axis_Length     59.532406
# Eccentricity           0.777233
# Convex_Area              7723.0
# Extent                 0.497413
# Class                    Cammeo
# dtype: object
#
#
# Max of features:
#  Area                    18913.0
# Perimeter            548.445984
# Major_Axis_Length    239.010498
# Minor_Axis_Length     107.54245
# Eccentricity           0.948007
# Convex_Area             19099.0
# Extent                  0.86105
# Class                  Osmancik
# dtype: object

# %%
#found count of nulls
Rice.isnull().sum()
# Out:
# Area                 2
# Perimeter            0
# Major_Axis_Length    3
# Minor_Axis_Length    1
# Eccentricity         0
# Convex_Area          4
# Extent               1
# Class                0
# dtype: int64

# %%
#delete nulls
Rice.dropna(inplace=True)
Rice
# Out:
#          Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0      7551.0  369.063995         163.408829          59.532406      0.931275
# 1      8546.0  388.580994         172.519959          63.344753      0.930152
# 2      7833.0  373.157013         162.516434          63.565002      0.920336
# 3      9292.0  414.118988         183.639710          64.871071      0.935528
# 4      7943.0  362.673004         154.886322          65.930885      0.904877
# ...       ...         ...                ...                ...           ...
# 3822  10151.0  420.899994         181.995575          72.099510      0.918181
# 3823  10222.0  423.497009         182.800247          72.124298      0.918873
# 3824   9216.0  384.342011         163.291626          72.260796      0.896756
# 3825  11377.0  452.407989         201.306259          72.281418      0.933314
# 3826   9598.0  397.000000         172.006790          72.283646      0.907414
#
# ...

# %%
#found count of duplicates
Rice.duplicated().sum()
# Out:
# 16

# %%
#delete duplicates
Rice.drop_duplicates(inplace=True)
Rice
# Out:
#          Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0      7551.0  369.063995         163.408829          59.532406      0.931275
# 1      8546.0  388.580994         172.519959          63.344753      0.930152
# 2      7833.0  373.157013         162.516434          63.565002      0.920336
# 3      9292.0  414.118988         183.639710          64.871071      0.935528
# 4      7943.0  362.673004         154.886322          65.930885      0.904877
# ...       ...         ...                ...                ...           ...
# 3812  18313.0  538.497986         222.464249         106.184746      0.878734
# 3813  17404.0  521.864990         211.063019         106.337822      0.863809
# 3814  18913.0  541.745972         227.135483         106.948357      0.882209
# 3815  17948.0  526.918030         214.093826         107.542450      0.864685
# 3826   9598.0  397.000000         172.006790          72.283646      0.907414
#
# ...

# %%
#feature means
Rice.mean()
# Out:
# <ipython-input-43-4e161fc5aa23>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Rice.mean()
# Area                 12672.520789
# Perimeter              454.333554
# Major_Axis_Length      188.818005
# Minor_Axis_Length       86.328101
# Eccentricity             0.886885
# Convex_Area          12957.439474
# Extent                   0.661945
# dtype: float64

# %%
#feature stds
Rice.std()
# Out:
# <ipython-input-44-e5451c836692>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Rice.std()
# Area                 1731.227144
# Perimeter              35.582385
# Major_Axis_Length      17.445782
# Minor_Axis_Length       5.720103
# Eccentricity            0.020797
# Convex_Area          1775.793357
# Extent                  0.077269
# dtype: float64

# %%
#drop labels for Computing
Rice2=Rice.drop(['Class'],axis=1)

#normalize
Rice2=(Rice2-Rice2.mean())/Rice2.std()
Rice2
# Out:
#           Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0    -2.958318  -2.396398          -1.456465          -4.684478      2.134477
# 1    -2.383581  -1.847896          -0.934211          -4.017995      2.080478
# 2    -2.795428  -2.281369          -1.507618          -3.979491      1.608443
# 3    -1.952673  -1.130182          -0.296822          -3.751161      2.338968
# 4    -2.731889  -2.576009          -1.944979          -3.565882      0.865141
# ...        ...        ...                ...                ...           ...
# 3812  3.258082   2.365340           1.928618           3.471379     -0.391920
# 3813  2.733020   1.897890           1.275094           3.498140     -1.109605
# 3814  3.604657   2.456621           2.196375           3.604875     -0.224813
# 3815  3.047248   2.039899           1.448821           3.708735     -1.067463
# 3826 -1.775920  -1.611290          -0.963626          -2.455280      0.987136
#
#       Convex_Area    Extent
# ...

# %%
#check mean and std to be true
print(Rice2.mean())
print(Rice2.std())
# Out:
# Area                -4.786814e-16
# Perimeter            4.487638e-16
# Major_Axis_Length   -5.983518e-16
# Minor_Axis_Length   -2.991759e-16
# Eccentricity        -6.611787e-15
# Convex_Area         -5.385166e-16
# Extent              -2.505598e-16
# dtype: float64
# Area                 1.0
# Perimeter            1.0
# Major_Axis_Length    1.0
# Minor_Axis_Length    1.0
# Eccentricity         1.0
# Convex_Area          1.0
# Extent               1.0
# dtype: float64

# %%
#get new data from user
new_data=[0,0,0,0,0,0,0]
print("input your data in this order: Area Perimeter Major_Axis_Length	Minor_Axis_Length	Eccentricity	Convex_Area	Extent")
for i in range(7):
  new_data[i]=float(input())
new_data
# Out:
# input your data in this order: Area Perimeter Major_Axis_Length	Minor_Axis_Length	Eccentricity	Convex_Area	Extent
# 12006
# 463.3
# 198.9
# 77.8
# 0.92
# 12344
# 0.53
# [12006.0, 463.3, 198.9, 77.8, 0.92, 12344.0, 0.53]

# %%
#normalize new data
new_data=(new_data-Rice.mean())/Rice.std()
new_data
# Out:
# <ipython-input-48-026ecba61899>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data=(new_data-Rice.mean())/Rice.std()
# <ipython-input-48-026ecba61899>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data=(new_data-Rice.mean())/Rice.std()
# Area                -0.384999
# Perimeter            0.251991
# Major_Axis_Length    0.577904
# Minor_Axis_Length   -1.490900
# Eccentricity         1.592306
# Convex_Area         -0.345445
# Extent              -1.707609
# dtype: float64

# %%
#calculate new data and primitive data distance
#in new column "distance"
Rice2['distance']=np.zeros(3800)
for i in range(7):
  Rice2['distance']+=abs(Rice2-new_data).iloc[:, i]
Rice2['distance']
# Out:
# 0       16.524872
# 1       13.345318
# 2       15.074657
# 3        8.839993
# 4       13.919094
#           ...
# 3812    18.868380
# 3813    18.191692
# 3814    22.077252
# 3815    19.081732
# 3826    11.270493
# Name: distance, Length: 3800, dtype: float64

# %%
#return "class" column to dataframe
Rice2['Class']=Rice['Class']
Rice2
# Out:
#           Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0    -2.958318  -2.396398          -1.456465          -4.684478      2.134477
# 1    -2.383581  -1.847896          -0.934211          -4.017995      2.080478
# 2    -2.795428  -2.281369          -1.507618          -3.979491      1.608443
# 3    -1.952673  -1.130182          -0.296822          -3.751161      2.338968
# 4    -2.731889  -2.576009          -1.944979          -3.565882      0.865141
# ...        ...        ...                ...                ...           ...
# 3812  3.258082   2.365340           1.928618           3.471379     -0.391920
# 3813  2.733020   1.897890           1.275094           3.498140     -1.109605
# 3814  3.604657   2.456621           2.196375           3.604875     -0.224813
# 3815  3.047248   2.039899           1.448821           3.708735     -1.067463
# 3826 -1.775920  -1.611290          -0.963626          -2.455280      0.987136
#
# ...

# %%
#return copy df to primary df
Rice=Rice2

# %%
#sort datas relative to distance
Rice=Rice.sort_values('distance')
Rice
# Out:
#           Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 266  -0.384999   0.254268           0.581827          -1.487662      1.608847
# 288  -0.414458  -0.006957           0.459568          -1.434119      1.489414
# 303  -0.151061   0.328659           0.899667          -1.404191      1.775724
# 334  -0.186874   0.374664           0.795023          -1.337934      1.668887
# 176  -0.502257   0.266296           0.735576          -1.731401      1.851926
# ...        ...        ...                ...                ...           ...
# 3812  3.258082   2.365340           1.928618           3.471379     -0.391920
# 3815  3.047248   2.039899           1.448821           3.708735     -1.067463
# 3804  2.994107   2.138206           1.976085           2.897356      0.028856
# 2104 -1.704294  -2.264619          -2.496508           0.126986     -4.151927
# 3814  3.604657   2.456621           2.196375           3.604875     -0.224813
#
# ...

# %%
#Voting between k closer data
print(Rice['Class'].head(10).mode())
# Out:
# 0    Cammeo
# Name: Class, dtype: object
